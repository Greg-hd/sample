# %%
import pandas as pd
df = pd.read_csv("2018-QS-World-University-Rankings.csv",encoding="latin-1")

# %%
df.shape
# Out:
# (985, 22)

# %%
df.head(50)
# Out:
#      2018   2017                                   Institution Name  \
# 0     NaN    NaN                                                NaN
# 1       1      1       MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)
# 2       2      2                                STANFORD UNIVERSITY
# 3       3      3                                 HARVARD UNIVERSITY
# 4       4      5       CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)
# 5       5      4                            UNIVERSITY OF CAMBRIDGE
# 6       6      6                               UNIVERSITY OF OXFORD
# 7       7      7                    UCL (UNIVERSITY COLLEGE LONDON)
# 8       8      9                            IMPERIAL COLLEGE LONDON
# 9       9     10                              UNIVERSITY OF CHICAGO
# 10     10      8  ETH ZURICH (SWISS FEDERAL INSTITUTE OF TECHNOL...
# 11     11     13             NANYANG TECHNOLOGICAL UNIVERSITY (NTU)
# 12     12     14    ECOLE POLYTECHNIQUE FÉDÉRALE DE LAUSANNE (EPFL)
# ...
